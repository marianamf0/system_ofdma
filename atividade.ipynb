# %% [markdown]
# # **Avaliação Parcial II**
#
# Disciplina: Sistemas de Comunicações Móveis I
#
# Discente:
# - Francisco Cassimiro de Sousa Albuquerque - 587132
# - Mariana Marques Ferreira - 587140

# %%
from graphic import graphic_cdf_per_scheduler
from simulation import analysis_per_scheduler

# %% [markdown]
# ## **Em cenário de propagação normal**

# %%
result_1 = analysis_per_scheduler(number_subcarriers=32, path_loss_exponent=4, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_1, title_xlabel="Capacity (Mbps)", title_parameters="N=32, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.02, 90th=0.60
# Total Cell Capacity (Mbps): 10th=3.97, 50th=7.38, 90th=15.65
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.35
# Total Cell Capacity (Mbps): 10th=22.30, 50th=40.91, 90th=61.49
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.57
# Total Cell Capacity (Mbps): 10th=4.23, 50th=8.58, 90th=14.97
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=42.01, 50th=79.37, 90th=106.31

# %%
result_2 = analysis_per_scheduler(number_subcarriers=64, path_loss_exponent=4, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_2, title_xlabel="Capacity (Mbps)", title_parameters="N=64, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=0.61
# Total Cell Capacity (Mbps): 10th=4.32, 50th=7.70, 90th=16.16
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.07
# Total Cell Capacity (Mbps): 10th=21.86, 50th=39.46, 90th=61.97
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.58
# Total Cell Capacity (Mbps): 10th=4.67, 50th=8.08, 90th=15.17
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.07
# Total Cell Capacity (Mbps): 10th=42.29, 50th=78.64, 90th=106.18

# %%
result_3 = analysis_per_scheduler(number_subcarriers=128, path_loss_exponent=4, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_3, title_xlabel="Capacity (Mbps)", title_parameters="N=128, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.04, 90th=0.57
# Total Cell Capacity (Mbps): 10th=4.37, 50th=7.60, 90th=15.49
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.14
# Total Cell Capacity (Mbps): 10th=21.65, 50th=40.22, 90th=62.58
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.60
# Total Cell Capacity (Mbps): 10th=4.84, 50th=8.23, 90th=15.19
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.24
# Total Cell Capacity (Mbps): 10th=43.40, 50th=80.08, 90th=106.87

# %%
result_4 = analysis_per_scheduler(number_subcarriers=32, path_loss_exponent=4, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_4, title_xlabel="Capacity (Mbps)", title_parameters="N=32, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.01, 90th=0.48
# Total Cell Capacity (Mbps): 10th=3.01, 50th=6.41, 90th=13.34
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.50
# Total Cell Capacity (Mbps): 10th=16.88, 50th=46.98, 90th=83.05
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.28
# Total Cell Capacity (Mbps): 10th=2.99, 50th=7.41, 90th=13.39
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=39.66, 50th=91.26, 90th=133.36

# %%
result_5 = analysis_per_scheduler(number_subcarriers=64, path_loss_exponent=4, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_5, title_xlabel="Capacity (Mbps)", title_parameters="N=64, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=0.58
# Total Cell Capacity (Mbps): 10th=3.89, 50th=7.22, 90th=15.37
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.70
# Total Cell Capacity (Mbps): 10th=18.13, 50th=47.27, 90th=83.67
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.41
# Total Cell Capacity (Mbps): 10th=4.30, 50th=7.53, 90th=13.70
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=47.54, 50th=93.83, 90th=135.53

# %%
result_6 = analysis_per_scheduler(number_subcarriers=128, path_loss_exponent=4, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_6, title_xlabel="Capacity (Mbps)", title_parameters="N=128, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=0.62
# Total Cell Capacity (Mbps): 10th=4.55, 50th=8.04, 90th=15.79
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.68
# Total Cell Capacity (Mbps): 10th=23.48, 50th=52.29, 90th=87.40
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.48
# Total Cell Capacity (Mbps): 10th=4.63, 50th=8.15, 90th=14.58
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=48.03, 50th=97.60, 90th=143.89

# %% [markdown]
# # **Em cenário urbano denso com edificações**

# %%
result_1_n5 = analysis_per_scheduler(number_subcarriers=32, path_loss_exponent=5, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_1_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=32, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.02, 90th=1.20
# Total Cell Capacity (Mbps): 10th=8.00, 50th=13.94, 90th=24.91
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.69
# Total Cell Capacity (Mbps): 10th=41.17, 50th=72.38, 90th=99.05
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.86
# Total Cell Capacity (Mbps): 10th=6.50, 50th=12.65, 90th=22.54
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=71.54, 50th=113.79, 90th=144.52

# %%
result_2_n5 = analysis_per_scheduler(number_subcarriers=64, path_loss_exponent=5, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_2_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=64, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.06, 90th=1.12
# Total Cell Capacity (Mbps): 10th=8.90, 50th=14.37, 90th=26.77
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.76
# Total Cell Capacity (Mbps): 10th=41.49, 50th=73.19, 90th=97.64
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.96
# Total Cell Capacity (Mbps): 10th=7.40, 50th=12.62, 90th=22.82
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=70.93, 50th=115.79, 90th=144.70

# %%
result_3_n5 = analysis_per_scheduler(number_subcarriers=128, path_loss_exponent=5, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_3_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=128, R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.01, 50th=0.08, 90th=1.23
# Total Cell Capacity (Mbps): 10th=9.00, 50th=14.77, 90th=27.40
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.65
# Total Cell Capacity (Mbps): 10th=42.45, 50th=72.38, 90th=97.03
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.92
# Total Cell Capacity (Mbps): 10th=7.45, 50th=12.22, 90th=21.39
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=71.71, 50th=116.99, 90th=144.74

# %%
result_4_n5 = analysis_per_scheduler(number_subcarriers=32, path_loss_exponent=5, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_4_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=32, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.01, 90th=0.75
# Total Cell Capacity (Mbps): 10th=4.64, 50th=9.22, 90th=18.30
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.28
# Total Cell Capacity (Mbps): 10th=29.11, 50th=70.37, 90th=117.18
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.23
# Total Cell Capacity (Mbps): 10th=3.87, 50th=9.33, 90th=16.89
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=58.49, 50th=119.34, 90th=171.61

# %%
result_5_n5 = analysis_per_scheduler(number_subcarriers=64, path_loss_exponent=5, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_5_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=64, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=0.85
# Total Cell Capacity (Mbps): 10th=6.20, 50th=10.68, 90th=20.50
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.61
# Total Cell Capacity (Mbps): 10th=36.29, 50th=77.75, 90th=121.33
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.62
# Total Cell Capacity (Mbps): 10th=6.02, 50th=10.28, 90th=18.50
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=64.71, 50th=125.46, 90th=173.13

# %%
result_6_n5 = analysis_per_scheduler(number_subcarriers=128, path_loss_exponent=5, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_6_n5, title_xlabel="Capacity (Mbps)", title_parameters="N=128, R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.04, 90th=0.92
# Total Cell Capacity (Mbps): 10th=7.40, 50th=12.24, 90th=22.85
#
# === Max-SINR Scheduler (Uniform Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.73
# Total Cell Capacity (Mbps): 10th=40.36, 50th=84.30, 90th=126.97
#
# === Round-Robin Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.73
# Total Cell Capacity (Mbps): 10th=6.40, 50th=11.17, 90th=20.21
#
# === Max-SINR Scheduler (Inverse Pathloss Power) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=68.45, 50th=125.33, 90th=174.88
