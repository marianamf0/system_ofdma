# %% [markdown]
# # **Avaliação Parcial II**
#
# Disciplina: Sistemas de Comunicações Móveis I
#
# Discente:
# - Francisco Cassimiro de Sousa Albuquerque - 587132
# - Mariana Marques Ferreira - 587140

# %%
from graphic import graphic_cdf_per_scheduler
from simulation import analysis_per_scheduler

# %% [markdown]
# ## **Em cenário de propagação normal**

# %%
result_1km = analysis_per_scheduler(path_loss_exponent=4, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_1km, title_xlabel="Capacity (Mbps)", title_parameters="R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.02, 90th=0.62
# Total Cell Capacity (Mbps): 10th=3.56, 50th=7.78, 90th=15.53
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.44
# Total Cell Capacity (Mbps): 10th=3.93, 50th=8.22, 90th=14.82
#
# === Max-SINR Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.30
# Total Cell Capacity (Mbps): 10th=22.55, 50th=41.20, 90th=61.28
#
# === Max-SINR Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=45.72, 50th=80.56, 90th=107.67
#
# === Round-Robin Scheduler (Uniform Power and N = 64) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.04, 90th=0.64
# Total Cell Capacity (Mbps): 10th=4.48, 50th=7.85, 90th=15.49
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 64) ===
# ...

# %%
result_2km = analysis_per_scheduler(path_loss_exponent=4, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_2km, title_xlabel="Capacity (Mbps)", title_parameters="R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.01, 90th=0.43
# Total Cell Capacity (Mbps): 10th=2.99, 50th=6.36, 90th=14.13
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.26
# Total Cell Capacity (Mbps): 10th=3.16, 50th=7.44, 90th=14.21
#
# === Max-SINR Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.55
# Total Cell Capacity (Mbps): 10th=17.86, 50th=46.94, 90th=85.04
#
# === Max-SINR Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=44.48, 50th=94.43, 90th=136.00
#
# === Round-Robin Scheduler (Uniform Power and N = 64) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.02, 90th=0.52
# Total Cell Capacity (Mbps): 10th=3.77, 50th=7.16, 90th=15.17
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 64) ===
# ...

# %% [markdown]
# # **Em cenário urbano denso com edificações**

# %%
result_1km_n5 = analysis_per_scheduler(path_loss_exponent=5, cell_radius=1000, verbose=True)
graphic_cdf_per_scheduler(output=result_1km_n5, title_xlabel="Capacity (Mbps)", title_parameters="R=1km")
# Out:
# === Round-Robin Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=1.30
# Total Cell Capacity (Mbps): 10th=8.26, 50th=14.24, 90th=25.43
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.87
# Total Cell Capacity (Mbps): 10th=6.61, 50th=12.67, 90th=21.81
#
# === Max-SINR Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=1.62
# Total Cell Capacity (Mbps): 10th=43.48, 50th=72.05, 90th=99.03
#
# === Max-SINR Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=70.50, 50th=115.13, 90th=145.69
#
# === Round-Robin Scheduler (Uniform Power and N = 64) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.06, 90th=1.14
# Total Cell Capacity (Mbps): 10th=8.84, 50th=14.43, 90th=26.16
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 64) ===
# ...

# %%
result_2km_n5 = analysis_per_scheduler(path_loss_exponent=5, cell_radius=2000, verbose=True)
graphic_cdf_per_scheduler(output=result_2km_n5, title_xlabel="Capacity (Mbps)", title_parameters="R=2km")
# Out:
# === Round-Robin Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.01, 90th=0.72
# Total Cell Capacity (Mbps): 10th=4.52, 50th=9.51, 90th=18.50
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.28
# Total Cell Capacity (Mbps): 10th=4.28, 50th=9.25, 90th=17.72
#
# === Max-SINR Scheduler (Uniform Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.24
# Total Cell Capacity (Mbps): 10th=29.81, 50th=70.38, 90th=116.06
#
# === Max-SINR Scheduler (Inverse Pathloss Power and N = 32) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.00, 90th=0.00
# Total Cell Capacity (Mbps): 10th=57.40, 50th=115.00, 90th=167.91
#
# === Round-Robin Scheduler (Uniform Power and N = 64) ===
# Per-UE Capacity (Mbps): 10th=0.00, 50th=0.03, 90th=0.87
# Total Cell Capacity (Mbps): 10th=6.04, 50th=10.98, 90th=21.87
#
# === Round-Robin Scheduler (Inverse Pathloss Power and N = 64) ===
# ...
